# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\arist\pycharmprojects\recomender\.venv\lib\site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip

# %%
pip install rectools[lightfm]
# Out:
# Requirement already satisfied: rectools[lightfm] in c:\users\arist\pycharmprojects\recomender\.venv\lib\site-packages (0.12.0)
# Requirement already satisfied: attrs<24.0.0,>=19.1.0 in c:\users\arist\pycharmprojects\recomender\.venv\lib\site-packages (from rectools[lightfm]) (23.2.0)
# Requirement already satisfied: implicit<0.8.0,>=0.7.1 in c:\users\arist\pycharmprojects\recomender\.venv\lib\site-packages (from rectools[lightfm]) (0.7.2)
# Requirement already satisfied: numpy<2.0.0,>=1.26 in c:\users\arist\pycharmprojects\recomender\.venv\lib\site-packages (from rectools[lightfm]) (1.26.4)
# Requirement already satisfied: pandas<3.0.0,>=1.5.0 in c:\users\arist\pycharmprojects\recomender\.venv\lib\site-packages (from rectools[lightfm]) (2.2.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.8.2 in c:\users\arist\pycharmprojects\recomender\.venv\lib\site-packages (from rectools[lightfm]) (2.10.6)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.20.1 in c:\users\arist\pycharmprojects\recomender\.venv\lib\site-packages (from rectools[lightfm]) (2.27.2)
# Requirement already satisfied: rectools-lightfm<2.0.0,>=1.17.3 in c:\users\arist\pycharmprojects\recomender\.venv\lib\site-packages (from rectools[lightfm]) (1.17.3)
# Requirement already satisfied: scipy<1.13,>=1.10.1 in c:\users\arist\pycharmprojects\recomender\.venv\lib\site-packages (from rectools[lightfm]) (1.12.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.27.0 in c:\users\arist\pycharmprojects\recomender\.venv\lib\site-packages (from rectools[lightfm]) (4.67.1)
# Requirement already satisfied: typeguard<5.0.0,>=4.1.0 in c:\users\arist\pycharmprojects\recomender\.venv\lib\site-packages (from rectools[lightfm]) (4.4.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.12.2 in c:\users\arist\pycharmprojects\recomender\.venv\lib\site-packages (from rectools[lightfm]) (4.12.2)
# Requirement already satisfied: threadpoolctl in c:\users\arist\pycharmprojects\recomender\.venv\lib\site-packages (from implicit<0.8.0,>=0.7.1->rectools[lightfm]) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\arist\pycharmprojects\recomender\.venv\lib\site-packages (from pandas<3.0.0,>=1.5.0->rectools[lightfm]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\arist\pycharmprojects\recomender\.venv\lib\site-packages (from pandas<3.0.0,>=1.5.0->rectools[lightfm]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\arist\pycharmprojects\recomender\.venv\lib\site-packages (from pandas<3.0.0,>=1.5.0->rectools[lightfm]) (2025.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\arist\pycharmprojects\recomender\.venv\lib\site-packages (from pydantic<3.0.0,>=2.8.2->rectools[lightfm]) (0.6.0)
# Requirement already satisfied: requests in c:\users\arist\pycharmprojects\recomender\.venv\lib\site-packages (from rectools-lightfm<2.0.0,>=1.17.3->rectools[lightfm]) (2.31.0)
# Requirement already satisfied: scikit-learn in c:\users\arist\pycharmprojects\recomender\.venv\lib\site-packages (from rectools-lightfm<2.0.0,>=1.17.3->rectools[lightfm]) (1.6.1)
# Requirement already satisfied: colorama in c:\users\arist\pycharmprojects\recomender\.venv\lib\site-packages (from tqdm<5.0.0,>=4.27.0->rectools[lightfm]) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\arist\pycharmprojects\recomender\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=1.5.0->rectools[lightfm]) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\arist\pycharmprojects\recomender\.venv\lib\site-packages (from requests->rectools-lightfm<2.0.0,>=1.17.3->rectools[lightfm]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arist\pycharmprojects\recomender\.venv\lib\site-packages (from requests->rectools-lightfm<2.0.0,>=1.17.3->rectools[lightfm]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\arist\pycharmprojects\recomender\.venv\lib\site-packages (from requests->rectools-lightfm<2.0.0,>=1.17.3->rectools[lightfm]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arist\pycharmprojects\recomender\.venv\lib\site-packages (from requests->rectools-lightfm<2.0.0,>=1.17.3->rectools[lightfm]) (2024.2.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\arist\pycharmprojects\recomender\.venv\lib\site-packages (from scikit-learn->rectools-lightfm<2.0.0,>=1.17.3->rectools[lightfm]) (1.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import warnings
from pathlib import Path
import os
import threadpoolctl

warnings.filterwarnings('ignore')


# lightfm extension is required for the LighFM section. You can install it with `pip install rectools[lightfm]`
try:
    from lightfm import LightFM
except ModuleNotFoundError:
    pass

from rectools import Columns
from rectools.dataset import Dataset
from rectools.models import (
    ImplicitALSWrapperModel,
    ImplicitBPRWrapperModel,
    LightFMWrapperModel,
    PureSVDModel,
    ImplicitItemKNNWrapperModel,
    EASEModel
)

# For vector models optimized ranking
os.environ["OPENBLAS_NUM_THREADS"] = "1"
threadpoolctl.threadpool_limits(1, "blas");

# %%
print(1)

# %%
pip install rectools[visuals]
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
from pprint import pprint

import numpy as np
import pandas as pd

from tqdm.auto import tqdm

from implicit.nearest_neighbours import TFIDFRecommender, BM25Recommender
from implicit.als import AlternatingLeastSquares

from rectools import Columns
from rectools.dataset import Dataset
from rectools.metrics import Precision, Recall, MeanInvUserFreq, Serendipity, calc_metrics
from rectools.models import ImplicitItemKNNWrapperModel, RandomModel, PopularModel
from rectools.model_selection import TimeRangeSplitter, cross_validate
from rectools.visuals import MetricsApp
from rectools.models import LightFMWrapperModel

# %%
import pickle

with open('cur/dataset.pkl', 'rb') as f:
    dataset = pickle.load(f)
aboba = pd.read_pickle('cur/dataset.pkl')
print(aboba)
# Out:
# Dataset(user_id_map=IdMap(external_ids=array([     34,       1,       3, ..., 3036571, 3036579, 3036583],
#       dtype=int64)), item_id_map=IdMap(external_ids=array([11690, 16970,     3, ..., 99052, 78096, 76603], dtype=int64)), interactions=Interactions(df=         user_id  item_id  weight                   datetime
# 0              0        0     7.0 2025-03-19 04:35:41.362820
# 1              0        1     8.0 2025-03-19 04:35:41.362820
# 2              1        2     7.0 2018-05-22 00:00:00.000000
# 3              1        3     5.6 2018-05-22 18:31:45.881993
# 4              1        4     7.0 2018-05-22 18:34:45.816208
# ...          ...      ...     ...                        ...
# 3046372        0        1     1.2 2025-03-19 00:35:36.589955
# 3046373        0        1     1.2 2025-03-19 00:35:36.589955
# 3046374        0        1     1.2 2025-03-19 00:35:36.589955
# 3046375        0        1     1.2 2025-03-19 00:35:36.589955
# 3046376        0        1     1.2 2025-03-19 00:35:36.589955
#
# [3046377 rows x 4 columns]), user_features=SparseFeatures(values=<2391407x11 sparse matrix of type '<class 'numpy.float32'>'
# 	with 7165980 stored elements in Compressed Sparse Row format>, names=(('age_group', '18_29'), ('age_group', '18+'), ('age_group', '60+'), ('age_group', '30_44'), ('age_group', '45_59'), ('sex', 1), ('sex', 2), ('sex', 0), ('preference', 0), ('preference', 1), ('preference', 2))), item_features=SparseFeatures(values=<21336x33 sparse matrix of type '<class 'numpy.float32'>'
# 	with 46 stored elements in Compressed Sparse Row format>, names=(('status_id', '__is_direct_feature'), ('type_id', 2), ('genres', 2), ('genres', 3), ('genres', 23), ('genres', 27), ('genres', 37), ('genres', 38), ('genres', 50), ('genres', 11), ('genres', 16), ('genres', 30), ('genres', 35), ('categories', 5), ('categories', 6), ('categories', 15), ('categories', 19), ('categories', 22), ('categories', 26), ('categories', 38), ('categories', 41), ('categories', 45), ('categories', 64), ('categories', 86), ('categories', 93), ('categories', 110), ('categories', 111), ('categories', 114), ('categories', 117), ('categories', 122), ('count_chapters', '100+'), ('age_limit', 0), ('relation_list', 0))))

# %%
interactions_df = aboba.interactions.df

# Преобразуем столбец datetime в тип datetime (если это еще не сделано)
interactions_df['datetime'] = pd.to_datetime(interactions_df['datetime'])

# Сортируем данные по убыванию времени
sorted_df = interactions_df.sort_values(by='datetime', ascending=False)

# Выводим результат
print(sorted_df.head(5))
# Out:
#          user_id  item_id  weight                   datetime
# 0              0        0     7.0 2025-03-19 04:35:41.362820
# 1              0        1     8.0 2025-03-19 04:35:41.362820
# 3046375        0        1     1.2 2025-03-19 00:35:36.589955
# 3046374        0        1     1.2 2025-03-19 00:35:36.589955
# 3046373        0        1     1.2 2025-03-19 00:35:36.589955

# %%
n_splits = 3

splitter = TimeRangeSplitter(
    test_size="14D",
    n_splits=n_splits,
    filter_already_seen=True,
    filter_cold_items=True,
    filter_cold_users=True,
)

# %%
splitter.get_test_fold_borders(dataset.interactions)
# Out:
# [(Timestamp('2025-02-06 00:00:00'), Timestamp('2025-02-20 00:00:00')),
#  (Timestamp('2025-02-20 00:00:00'), Timestamp('2025-03-06 00:00:00')),
#  (Timestamp('2025-03-06 00:00:00'), Timestamp('2025-03-20 00:00:00'))]

# %%
models = {
    "lighfm": LightFMWrapperModel(LightFM(no_components=100, loss="bpr", random_state=60)),
}

# We will calculate several classic (precision@k and recall@k) and "beyond accuracy" metrics
metrics = {
    "prec@1": Precision(k=1),
    "prec@10": Precision(k=10),
    "recall@10": Recall(k=10),
    "novelty@10": MeanInvUserFreq(k=10),
    "serendipity@10": Serendipity(k=10),
}

K_RECS = 10

# %%
# %%time

# For each fold generate train and test part of dataset
# Then fit every model, generate recommendations and calculate metrics

cv_results = cross_validate(
    dataset=dataset,
    splitter=splitter,
    models=models,
    metrics=metrics,
    k=K_RECS,
    filter_viewed=True,
)

# %%
pd.DataFrame(cv_results["splits"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 pd.DataFrame(cv_results["splits"])
#
# NameError: name 'cv_results' is not defined

# %%
pd.DataFrame(cv_results["metrics"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 pd.DataFrame(cv_results["metrics"])
#
# NameError: name 'cv_results' is not defined

# %%
pivot_results = (
    pd.DataFrame(cv_results["metrics"])
    .drop(columns="i_split")
    .groupby(["model"], sort=False)
    .agg(["mean"])
)
pivot_results.columns = pivot_results.columns.droplevel(1)

(
    pivot_results.style
    .set_caption("Mean values of metrics")
    .highlight_min(color='lightcoral', axis=0)
    .highlight_max(color='lightgreen', axis=0)
)

# %%
metadata_example = {
    Columns.Model: ["lightfm"],
    "k": [40]
}

# %%
app = MetricsApp.construct(
    models_metrics=pd.DataFrame(cv_results["metrics"]),
    models_metadata=pd.DataFrame(metadata_example),  # optional
)

# %%
pip install -U kaleido

# %%
fig = app.fig
fig.update_layout(title="Metrics: prec@10 vs prec@1")
fig.show("png")
