# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\arist\pycharmprojects\recomender\.venv\lib\site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pickle
# Out:
# 821.99s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\arist\pycharmprojects\recomender\.venv\lib\site-packages (23.2.1)
# Collecting pip
#   Obtaining dependency information for pip from https://files.pythonhosted.org/packages/c9/bc/b7db44f5f39f9d0494071bddae6880eb645970366d0a200022a1a93d57f5/pip-25.0.1-py3-none-any.whl.metadata
#   Using cached pip-25.0.1-py3-none-any.whl.metadata (3.7 kB)
# Using cached pip-25.0.1-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.2.1
#     Uninstalling pip-23.2.1:
#       Successfully uninstalled pip-23.2.1
# Successfully installed pip-25.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (25.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install rectools[lightfm]
# Out:
# Requirement already satisfied: rectools[lightfm] in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (0.12.0)
# Requirement already satisfied: attrs<24.0.0,>=19.1.0 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from rectools[lightfm]) (23.2.0)
# Requirement already satisfied: implicit<0.8.0,>=0.7.1 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from rectools[lightfm]) (0.7.2)
# Requirement already satisfied: numpy<2.0.0,>=1.26 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from rectools[lightfm]) (1.26.4)
# Requirement already satisfied: pandas<3.0.0,>=1.5.0 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from rectools[lightfm]) (2.2.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.8.2 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from rectools[lightfm]) (2.10.6)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.20.1 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from rectools[lightfm]) (2.27.2)
# Requirement already satisfied: rectools-lightfm<2.0.0,>=1.17.3 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from rectools[lightfm]) (1.17.3)
# Requirement already satisfied: scipy<1.13,>=1.10.1 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from rectools[lightfm]) (1.12.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.27.0 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from rectools[lightfm]) (4.67.1)
# Requirement already satisfied: typeguard<5.0.0,>=4.1.0 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from rectools[lightfm]) (4.4.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.12.2 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from rectools[lightfm]) (4.12.2)
# Requirement already satisfied: threadpoolctl in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from implicit<0.8.0,>=0.7.1->rectools[lightfm]) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from pandas<3.0.0,>=1.5.0->rectools[lightfm]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from pandas<3.0.0,>=1.5.0->rectools[lightfm]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from pandas<3.0.0,>=1.5.0->rectools[lightfm]) (2025.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.8.2->rectools[lightfm]) (0.6.0)
# Requirement already satisfied: requests in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from rectools-lightfm<2.0.0,>=1.17.3->rectools[lightfm]) (2.31.0)
# Requirement already satisfied: scikit-learn in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from rectools-lightfm<2.0.0,>=1.17.3->rectools[lightfm]) (1.6.1)
# Requirement already satisfied: six>=1.5 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=1.5.0->rectools[lightfm]) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from requests->rectools-lightfm<2.0.0,>=1.17.3->rectools[lightfm]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from requests->rectools-lightfm<2.0.0,>=1.17.3->rectools[lightfm]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from requests->rectools-lightfm<2.0.0,>=1.17.3->rectools[lightfm]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from requests->rectools-lightfm<2.0.0,>=1.17.3->rectools[lightfm]) (2024.2.2)
# Requirement already satisfied: joblib>=1.2.0 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from scikit-learn->rectools-lightfm<2.0.0,>=1.17.3->rectools[lightfm]) (1.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import warnings
from pathlib import Path
import os
import threadpoolctl

warnings.filterwarnings('ignore')


# lightfm extension is required for the LighFM section. You can install it with `pip install rectools[lightfm]`
try:
    from lightfm import LightFM
except ModuleNotFoundError:
    pass

from rectools import Columns
from rectools.dataset import Dataset
from rectools.models import (
    ImplicitALSWrapperModel,
    ImplicitBPRWrapperModel,
    LightFMWrapperModel,
    PureSVDModel,
    ImplicitItemKNNWrapperModel,
    EASEModel
)

# For vector models optimized ranking
os.environ["OPENBLAS_NUM_THREADS"] = "1"
threadpoolctl.threadpool_limits(1, "blas");

# %%
print(1)
# Out:
# 1

# %%
pip install rectools[visuals]
# Out:
# Requirement already satisfied: rectools[visuals] in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (0.12.0)
# Requirement already satisfied: attrs<24.0.0,>=19.1.0 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from rectools[visuals]) (23.2.0)
# Requirement already satisfied: implicit<0.8.0,>=0.7.1 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from rectools[visuals]) (0.7.2)
# Requirement already satisfied: ipywidgets<8.2,>=7.7 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from rectools[visuals]) (8.1.5)
# Requirement already satisfied: nbformat>=4.2.0 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from rectools[visuals]) (5.10.4)
# Requirement already satisfied: numpy<2.0.0,>=1.26 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from rectools[visuals]) (1.26.4)
# Requirement already satisfied: pandas<3.0.0,>=1.5.0 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from rectools[visuals]) (2.2.3)
# Requirement already satisfied: plotly<6.0.0,>=5.22.0 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from rectools[visuals]) (5.24.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.8.2 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from rectools[visuals]) (2.10.6)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.20.1 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from rectools[visuals]) (2.27.2)
# Requirement already satisfied: scipy<1.13,>=1.10.1 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from rectools[visuals]) (1.12.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.27.0 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from rectools[visuals]) (4.67.1)
# Requirement already satisfied: typeguard<5.0.0,>=4.1.0 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from rectools[visuals]) (4.4.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.12.2 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from rectools[visuals]) (4.12.2)
# Requirement already satisfied: threadpoolctl in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from implicit<0.8.0,>=0.7.1->rectools[visuals]) (3.5.0)
# Requirement already satisfied: comm>=0.1.3 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from ipywidgets<8.2,>=7.7->rectools[visuals]) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from ipywidgets<8.2,>=7.7->rectools[visuals]) (9.0.2)
# Requirement already satisfied: traitlets>=4.3.1 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from ipywidgets<8.2,>=7.7->rectools[visuals]) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from ipywidgets<8.2,>=7.7->rectools[visuals]) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from ipywidgets<8.2,>=7.7->rectools[visuals]) (3.0.13)
# Requirement already satisfied: fastjsonschema>=2.15 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from nbformat>=4.2.0->rectools[visuals]) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from nbformat>=4.2.0->rectools[visuals]) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from nbformat>=4.2.0->rectools[visuals]) (5.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from pandas<3.0.0,>=1.5.0->rectools[visuals]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from pandas<3.0.0,>=1.5.0->rectools[visuals]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from pandas<3.0.0,>=1.5.0->rectools[visuals]) (2025.1)
# Requirement already satisfied: tenacity>=6.2.0 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from plotly<6.0.0,>=5.22.0->rectools[visuals]) (9.0.0)
# Requirement already satisfied: packaging in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from plotly<6.0.0,>=5.22.0->rectools[visuals]) (24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.8.2->rectools[visuals]) (0.6.0)
# Requirement already satisfied: decorator in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<8.2,>=7.7->rectools[visuals]) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<8.2,>=7.7->rectools[visuals]) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<8.2,>=7.7->rectools[visuals]) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<8.2,>=7.7->rectools[visuals]) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<8.2,>=7.7->rectools[visuals]) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<8.2,>=7.7->rectools[visuals]) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<8.2,>=7.7->rectools[visuals]) (2.19.1)
# Requirement already satisfied: stack_data in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<8.2,>=7.7->rectools[visuals]) (0.6.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->rectools[visuals]) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->rectools[visuals]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->rectools[visuals]) (0.23.1)
# Requirement already satisfied: platformdirs>=2.5 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->rectools[visuals]) (4.3.6)
# Requirement already satisfied: six>=1.5 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=1.5.0->rectools[visuals]) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets<8.2,>=7.7->rectools[visuals]) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets<8.2,>=7.7->rectools[visuals]) (0.7.0)
# Requirement already satisfied: wcwidth in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets<8.2,>=7.7->rectools[visuals]) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets<8.2,>=7.7->rectools[visuals]) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets<8.2,>=7.7->rectools[visuals]) (3.0.0)
# Requirement already satisfied: pure-eval in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets<8.2,>=7.7->rectools[visuals]) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pprint import pprint

import numpy as np
import pandas as pd

from tqdm.auto import tqdm

from implicit.nearest_neighbours import TFIDFRecommender, BM25Recommender
from implicit.als import AlternatingLeastSquares

from rectools import Columns
from rectools.dataset import Dataset
from rectools.metrics import Precision, Recall, MeanInvUserFreq, Serendipity, calc_metrics
from rectools.models import ImplicitItemKNNWrapperModel, RandomModel, PopularModel
from rectools.model_selection import TimeRangeSplitter, cross_validate
from rectools.visuals import MetricsApp
from rectools.models import LightFMWrapperModel

# %%
pip install unzip
# Out:
# 62.22s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Requirement already satisfied: unzip in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (1.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !wget -q https://files.grouplens.org/datasets/movielens/ml-1m.zip -O ml-1m.zip
# !unzip -o ml-1m.zip
# !rm ml-1m.zip
# Out:
# 75.13s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 82.98s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Archive:  ml-1m.zip
#   inflating: ml-1m/movies.dat
#   inflating: ml-1m/ratings.dat
#   inflating: ml-1m/README
#   inflating: ml-1m/users.dat
# 88.82s - pydevd: Sending message related to process being replaced timed-out after 5 seconds

# %%
# %%time
ratings = pd.read_csv(
    "ml-1m/ratings.dat",
    sep="::",
    engine="python",  # Because of 2-chars separators
    header=None,
    names=[Columns.User, Columns.Item, Columns.Weight, Columns.Datetime],
)
print(ratings.shape)
ratings.head()
# Out:
# (1000209, 4)
# CPU times: user 4.99 s, sys: 697 ms, total: 5.69 s
# Wall time: 5.28 s
#    user_id  item_id  weight   datetime
# 0        1     1193       5  978300760
# 1        1      661       3  978302109
# 2        1      914       3  978301968
# 3        1     3408       4  978300275
# 4        1     2355       5  978824291

# %%
ratings["user_id"].nunique(), ratings["item_id"].nunique()
# Out:
# (6040, 3706)

# %%
ratings["weight"].value_counts()
# Out:
# weight
# 4    348971
# 3    261197
# 5    226310
# 2    107557
# 1     56174
# Name: count, dtype: int64

# %%
ratings["datetime"] = pd.to_datetime(ratings["datetime"] * 10 ** 9)
print("Time period")
ratings["datetime"].min(), ratings["datetime"].max()
# Out:
# Time period
# (Timestamp('2000-04-25 23:05:32'), Timestamp('2003-02-28 17:49:50'))

# %%
# %%time
import pickle
with open('cur/dataset.pkl' ,'rb') as f:
    dataset = pickle.load(f)
red = pd.read_pickle('cur/dataset.pkl')
print(red.interactions)
# Out:
# Interactions(df=         user_id  item_id  weight                   datetime
# 0              0        0     7.0 2025-03-18 17:45:18.480798
# 1              1        1     8.0 2025-03-18 17:45:18.480798
# 2              1        2     7.0 2025-03-18 17:45:18.480798
# 3              1        3     8.0 2025-03-18 17:45:18.480798
# 4              1        4     8.0 2025-03-18 17:45:18.480798
# ...          ...      ...     ...                        ...
# 5698015        0    21491     1.2 2025-01-16 23:50:22.240803
# 5698016        0    21491     1.2 2025-01-16 23:50:22.240803
# 5698017        0    21092     1.2 2025-01-16 23:44:20.236510
# 5698018        0    21811     1.2 2025-01-17 00:00:58.083622
# 5698019        2    21092     1.2 2025-01-21 17:17:36.128940
#
# [5698020 rows x 4 columns])
# CPU times: user 572 ms, sys: 428 ms, total: 1 s
# Wall time: 3.4 s

# %%
n_splits = 3

splitter = TimeRangeSplitter(
    test_size="14D",
    n_splits=n_splits,
    filter_already_seen=True,
    filter_cold_items=True,
    filter_cold_users=True,
)

# %%
splitter.get_test_fold_borders(dataset.interactions)
# Out:
# [(Timestamp('2025-02-05 00:00:00'), Timestamp('2025-02-19 00:00:00')),
#  (Timestamp('2025-02-19 00:00:00'), Timestamp('2025-03-05 00:00:00')),
#  (Timestamp('2025-03-05 00:00:00'), Timestamp('2025-03-19 00:00:00'))]

# %%
models = {
    "lighfm": LightFMWrapperModel(LightFM(no_components=10, loss="bpr", random_state=60)),
}

# We will calculate several classic (precision@k and recall@k) and "beyond accuracy" metrics
metrics = {
    "prec@1": Precision(k=1),
    "prec@10": Precision(k=10),
    "recall@10": Recall(k=10),
    "novelty@10": MeanInvUserFreq(k=10),
    "serendipity@10": Serendipity(k=10),
}

K_RECS = 10

# %%
# %%time

# For each fold generate train and test part of dataset
# Then fit every model, generate recommendations and calculate metrics

cv_results = cross_validate(
    dataset=dataset,
    splitter=splitter,
    models=models,
    metrics=metrics,
    k=K_RECS,
    filter_viewed=True,
)
# Out:
# CPU times: user 1min 9s, sys: 2.2 s, total: 1min 11s
# Wall time: 1min 11s

# %%
pd.DataFrame(cv_results["splits"])
# Out:
#    i_split      start        end    train  train_users  train_items  test  \
# 0        0 2025-02-05 2025-02-19  5697942       309789        24626     0
# 1        1 2025-02-19 2025-03-05  5697942       309789        24626     0
# 2        2 2025-03-05 2025-03-19  5697942       309789        24626    44
#
#    test_users  test_items
# 0           0           0
# 1           0           0
# 2           8          42

# %%
pd.DataFrame(cv_results["metrics"])
# Out:
#     model  i_split  prec@1  prec@10  recall@10  novelty@10  serendipity@10
# 0  lighfm        0     NaN      NaN        NaN         NaN             NaN
# 1  lighfm        1     NaN      NaN        NaN         NaN             NaN
# 2  lighfm        2   0.125     0.05   0.029762    9.037165        0.000055

# %%
pivot_results = (
    pd.DataFrame(cv_results["metrics"])
    .drop(columns="i_split")
    .groupby(["model"], sort=False)
    .agg(["mean"])
)
pivot_results.columns = pivot_results.columns.droplevel(1)

(
    pivot_results.style
    .set_caption("Mean values of metrics")
    .highlight_min(color='lightcoral', axis=0)
    .highlight_max(color='lightgreen', axis=0)
)
# Out:
# <style type="text/css">
# #T_398a0_row0_col0, #T_398a0_row0_col1, #T_398a0_row0_col2, #T_398a0_row0_col3, #T_398a0_row0_col4 {
#   background-color: lightcoral;
#   background-color: lightgreen;
# }
# </style>
# <table id="T_398a0">
#   <caption>Mean values of metrics</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_398a0_level0_col0" class="col_heading level0 col0" >prec@1</th>
#       <th id="T_398a0_level0_col1" class="col_heading level0 col1" >prec@10</th>
#       <th id="T_398a0_level0_col2" class="col_heading level0 col2" >recall@10</th>
#       <th id="T_398a0_level0_col3" class="col_heading level0 col3" >novelty@10</th>
#       <th id="T_398a0_level0_col4" class="col_heading level0 col4" >serendipity@10</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_398a0_level0_row0" class="row_heading level0 row0" >lighfm</th>
#       <td id="T_398a0_row0_col0" class="data row0 col0" >0.125000</td>
#       <td id="T_398a0_row0_col1" class="data row0 col1" >0.050000</td>
#       <td id="T_398a0_row0_col2" class="data row0 col2" >0.029762</td>
#       <td id="T_398a0_row0_col3" class="data row0 col3" >9.037165</td>
#       <td id="T_398a0_row0_col4" class="data row0 col4" >0.000055</td>
#     </tr>
#   </tbody>
# </table>

# %%
metadata_example = {
    Columns.Model: ["lightfm"],
    "k": [40]
}

# %%
app = MetricsApp.construct(
    models_metrics=pd.DataFrame(cv_results["metrics"]),
    models_metadata=pd.DataFrame(metadata_example),  # optional
)
# Out:
# VBox(children=(Tab(children=(VBox(children=(HBox(children=(Checkbox(value=True, description='Average folds'), …

# %%
pip install -U kaleido
# Out:
# 1069.97s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Requirement already satisfied: kaleido in /mnt/c/Users/arist/PycharmProjects/recomender/.re_venv/lib/python3.12/site-packages (0.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
fig = app.fig
fig.update_layout(title="Metrics: prec@10 vs prec@1")
fig.show("png")
